# %%
# %matplotlib inline
import flopy
import os

# %%
ml = flopy.modflow.Modflow.load(os.path.join('work', 'model1.nam'), verbose=True)
# Out:
# Creating new model with name: work/model1
# --------------------------------------------------
#
# Parsing the namefile --> ./work/model1.nam
# Setting filehandles:
#
# --------------------------------------------------
# External unit dictionary:
# {51: filename:./work/model1.hds, filetype:DATA(BINARY), 2: filename:./work/model1.list, filetype:LIST, 27: filename:./work/model1.pcg, filetype:PCG, 20: filename:./work/model1.wel, filetype:WEL, 53: filename:./work/model1.cbc, filetype:DATA(BINARY), 52: filename:./work/model1.ddn, filetype:DATA(BINARY), 11: filename:./work/model1.dis, filetype:DIS, 13: filename:./work/model1.bas, filetype:BAS6, 14: filename:./work/model1.oc, filetype:OC, 15: filename:./work/model1.lpf, filetype:LPF}
# --------------------------------------------------
#
# ModflowBas6 free format:True
#
# loading dis package file...
#    Loading dis package with:
#       2 layers, 101 rows, 101 columns, and 1 stress periods
#    loading laycbd...
#    loading delr...
# ...

# %%
ml.plot()
# Out:
# Plotting Packages
# plotting DIS package Util3d instance: botm
# plotting DIS package Util3d instance: _ModflowDis__thickness
# plotting DIS package Util2d instance: top
# plotting BAS6 package Util3d instance: ibound
# plotting BAS6 package Util3d instance: strt
# plotting WEL package MfList instance: stress_period_data
# plotting LPF package Util3d instance: vkcb
# plotting LPF package Util3d instance: sy
# plotting LPF package Util3d instance: vka
# plotting LPF package Util3d instance: hani
# plotting LPF package Util3d instance: wetdry
# plotting LPF package Util3d instance: ss
# plotting LPF package Util3d instance: hk
# /Users/jdhughes/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...

# %%
ml.wel.stress_period_data[0]
# Out:
# rec.array([(1, 50, 50, -1000.0)],
#           dtype=[('k', '<i8'), ('i', '<i8'), ('j', '<i8'), ('flux', '<f4')])

# %%
ml.wel.write_file()
